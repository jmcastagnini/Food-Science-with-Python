# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from anova_one_way import anova1
from graphic_letters import graphic_letters

# %%
df_result=anova1(df='color2.csv', treatment=2,col=3,factor='numeric')  # Statistical analysis as numeric (continuous)
df_result
# Out:
# {'L':                   L L-groups
#  0     64.76 ± 3.573        a
#  50   48.475 ± 2.902        b
#  100  57.988 ± 3.212        a,
#  'a':                   a a-groups
#  0    26.048 ± 3.485        a
#  50   22.085 ± 2.706        b
#  100  10.849 ± 0.762        c,
#  'b':                   b b-groups
#  0    17.016 ± 2.538       ab
#  50   18.597 ± 2.665        a
#  100  15.008 ± 1.073        b,
#  'C':                   C C-groups
#  0    31.155 ± 3.975        a
#  50   28.898 ± 3.579        a
#  100  18.534 ± 1.026        b,
#  'h':                  h h-groups
#  0    0.578 ± 0.057        c
#  50   0.699 ± 0.043        b
#  100  0.944 ± 0.043        a}

# %%
df_result=anova1(df='color2.csv', treatment=1,col=3)  # Statistical analysis as categoric
df_result
# Out:
# {'L':                            L L-groups
#  100Trehalose  57.988 ± 3.212        b
#  50Trehalose   48.475 ± 2.902        c
#  Control        64.76 ± 3.573        a,
#  'a':                            a a-groups
#  100Trehalose  10.849 ± 0.762        c
#  50Trehalose   22.085 ± 2.706        b
#  Control       26.048 ± 3.485        a,
#  'b':                            b b-groups
#  100Trehalose  15.008 ± 1.073        b
#  50Trehalose   18.597 ± 2.665        a
#  Control       17.016 ± 2.538       ab,
#  'C':                            C C-groups
#  100Trehalose  18.534 ± 1.026        b
#  50Trehalose   28.898 ± 3.579        a
#  Control       31.155 ± 3.975        a,
#  'h':                           h h-groups
#  100Trehalose  0.944 ± 0.043        a
#  50Trehalose   0.699 ± 0.043        b
#  Control       0.578 ± 0.057        c}

# %%
df = pd.read_csv('color2.csv', sep=';')  # Read the data frame
#df.replace(to_replace='P-05', value='P-5', inplace=True)  # Replace some values
df
# Out:
#           Sample  Treatment  Time      L      a      b      C     h
# 0        Control          0     0  63.69  31.41  20.97  37.77  0.59
# 1        Control          0     0  63.89  27.81  20.63  34.63  0.64
# 2        Control          0     0  66.31  29.11  17.82  34.13  0.55
# 3        Control          0     0  62.11  30.52  19.95  36.46  0.58
# 4        Control          0     0  64.56  25.93  17.76  31.43  0.60
# 5        Control          0     0  60.38  25.54  15.43  29.84  0.54
# 6        Control          0     0  64.30  27.99  15.82  32.15  0.51
# 7        Control          0     0  59.16  25.72  15.76  30.16  0.55
# 8        Control          0     0  66.33  23.73  13.11  27.11  0.50
# 9        Control          0     0  70.45  21.30  14.25  25.63  0.59
# 10       Control          0     0  71.35  20.43  17.57  26.95  0.71
# 11       Control          0     0  64.59  23.09  15.12  27.60  0.58
# 12   50Trehalose         50     0  51.85  17.63  14.43  22.78  0.69
# 13   50Trehalose         50     0  52.79  19.09  15.06  24.32  0.67
# 14   50Trehalose         50     0  50.25  20.55  15.86  25.96  0.66
# 15   50Trehalose         50     0  53.24  18.58  14.99  23.87  0.68
# 16   50Trehalose         50     0  46.48  22.17  20.48  30.18  0.75
# 17   50Trehalose         50     0  45.60  22.13  20.90  30.44  0.76
# 18   50Trehalose         50     0  47.22  22.78  20.86  30.89  0.74
# 19   50Trehalose         50     0  46.64  21.81  21.36  30.53  0.77
# 20   50Trehalose         50     0  48.45  25.84  19.89  32.61  0.66
# 21   50Trehalose         50     0  46.22  24.69  19.60  31.52  0.67
# 22   50Trehalose         50     0  48.29  24.73  20.20  31.93  0.68
# 23   50Trehalose         50     0  44.67  25.02  19.53  31.74  0.66
# 24  100Trehalose        100     0  59.91  10.66  15.21  18.57  0.96
# 25  100Trehalose        100     0  56.09  10.19  15.27  18.36  0.98
# 26  100Trehalose        100     0  62.07   9.83  15.37  18.24  1.00
# 27  100Trehalose        100     0  55.44  10.23  15.28  18.39  0.98
# 28  100Trehalose        100     0  61.54  10.56  16.56  19.64  1.00
# 29  100Trehalose        100     0  54.42  11.60  16.01  19.77  0.94
# 30  100Trehalose        100     0  56.66  11.77  15.40  19.38  0.92
# 31  100Trehalose        100     0  54.54  11.69  15.97  19.79  0.94
# 32  100Trehalose        100     0  60.26  12.19  14.42  18.88  0.87
# 33  100Trehalose        100     0  57.41  10.62  13.25  16.98  0.90
# 34  100Trehalose        100     0  63.08  10.23  14.33  17.61  0.95
# 35  100Trehalose        100     0  54.44  10.62  13.02  16.80  0.89

# %%
fig, ax = plt.subplots(1,3, figsize=(14,5))  # Create a figure of 1 row and 3 columns
#sns.set_theme(style="whitegrid")

# First place
ax[0].set_title('Luminosità')  # Title
chart=sns.barplot(ax=ax[0],x='Sample', y='L', data=df, ci='sd');  # Make the graphic
graphic_letters(chart=chart,df=df_result,analysis='L',xytext=(3,6),fontsize=13)  # Include the statistical letters

# Second place
ax[1].set_title('Croma')
#ax[1].set_ylim(0, -3.5)  # Change the limits of y axis
chart=sns.barplot(ax=ax[1],x='Sample', y='C', data=df, ci='sd');
graphic_letters(chart=chart,df=df_result,analysis='C',xytext=(3,6),fontsize=13)

# Third place
ax[2].set_title('Hue')
chart=sns.barplot(ax=ax[2],x='Sample', y='h', data=df, ci='sd');
graphic_letters(chart=chart,df=df_result,analysis='h',xytext=(3,6),fontsize=13)

# %%
fig.savefig('color.png',dpi=300)
#fig.savefig('color.pdf')
#fig.savefig('color.svg')
#fig.savefig('color.eps')

# %%
table = pd.DataFrame()
for key in df_result.keys():#chiavi
    table = pd.concat([table, df_result['{}'.format(key)]],axis=1)
table.to_excel('table_color.xlsx')
table
# Out:
#                   L L-groups               a a-groups               b  \
# 0     64.76 ± 3.573        a  26.048 ± 3.485        a  17.016 ± 2.538
# 50   48.475 ± 2.902        b  22.085 ± 2.706        b  18.597 ± 2.665
# 100  57.988 ± 3.212        a  10.849 ± 0.762        c  15.008 ± 1.073
#
#     b-groups               C C-groups              h h-groups
# 0         ab  31.155 ± 3.975        a  0.578 ± 0.057        c
# 50         a  28.898 ± 3.579        a  0.699 ± 0.043        b
# 100        b  18.534 ± 1.026        b  0.944 ± 0.043        a
